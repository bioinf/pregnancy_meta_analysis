# %%
import pandas as pd
import scipy.stats
from collections import Counter
from statsmodels.stats.multitest import fdrcorrection

GEST = 'out_data_fg/cor_full_GEST_DIABETES.txt'
HYPT = 'out_data_fg/cor_full_I9_HYPTENSPREG.txt'
VOMT = 'out_data_fg/cor_full_O15_EXCESS_VOMIT_PREG.txt'
HPRT = 'out_data_fg/cor_full_O15_GESTAT_HYPERT.txt'
FINN_UK = 'data/finn_uk_codes.csv'
PRIOR_LIST = ['2']

BONFERRONI = True
FDR = False

# %%
fu = pd.read_csv(FINN_UK)
fu = fu.loc[:,['0', 'finn_pheno']].drop_duplicates().rename(columns={'finn_pheno':'full_name'})
fu = pd.concat([fu, pd.DataFrame({'0':['GEST_DIABETES', 'O15_PRE_OR_ECLAMPSIA'],'full_name':['Gestational diabetes (for exclusion)','Pre-eclampsia or eclampsia']})])
fu.index = fu['0']
fu
# Out:
#                                                                        0  \
# 0
# E4_THYROID                                                    E4_THYROID
# C3_THYROID_GLAND                                        C3_THYROID_GLAND
# C3_THYROID_GLAND_EXALLC                          C3_THYROID_GLAND_EXALLC
# E4_THYTOXNOD                                                E4_THYTOXNOD
# I9_RHEUVALV                                                  I9_RHEUVALV
# ...                                                                  ...
# M13_SLE                                                          M13_SLE
# SLE_NOS                                                          SLE_NOS
# DRUGADVERS_SYSTEMIC_LUPUS_ERYTHEMAT  DRUGADVERS_SYSTEMIC_LUPUS_ERYTHEMAT
# GEST_DIABETES                                              GEST_DIABETES
# O15_PRE_OR_ECLAMPSIA                                O15_PRE_OR_ECLAMPSIA
#
#                                                                              full_name
# 0
# E4_THYROID                                              Disorders of the thyroid gland
# C3_THYROID_GLAND                                   Malignant neoplasm of thyroid gland
# C3_THYROID_GLAND_EXALLC              Malignant neoplasm of thyroid gland (all cance...
# E4_THYTOXNOD                           Thyrotoxicosis with toxic single thyroid nodule
# I9_RHEUVALV                                                   Rheumatic valve diseases
# ...                                                                                ...
# M13_SLE                                                   Systemic lupus erythematosus
# SLE_NOS                                      Systemic lupus erythematosus, unspecified
# DRUGADVERS_SYSTEMIC_LUPUS_ERYTHEMAT          Drug-induced systemic lupus erythematosus
# GEST_DIABETES                                     Gestational diabetes (for exclusion)
# O15_PRE_OR_ECLAMPSIA                                        Pre-eclampsia or eclampsia
#
# [1221 rows x 2 columns]

# %%
ph_map = {'I9_HYPTENSPREG':'HP', 'GEST_DIABETES':'GD', 'O15_GESTAT_HYPERT':'GH', 'O15_EXCESS_VOMIT_PREG': 'EV'}

# %%
def return_df(FILE):
    data = ''
    with open(FILE, 'r') as in_f:
        data = in_f.read().replace('\n--', '').split('\n')
    keys = list(map(lambda x: x.split('/')[0].replace('f_', ''), data[::2]))
    values = map(lambda x: x.split(' '), data[1::2])
    traits = map(lambda x: x.split('/')[-1].replace('.cors', ''), data[::2])
    data_dict = {k: v for k, v in zip(keys, values)}
    for k, v in zip(keys, traits):
        try:
            data_dict[k].append(v)
        except KeyError:
            print(k)
    return pd.DataFrame(data_dict, index=['Cor_All', 'cor', 'cor_std', 'trait']).T


def count_sign(data):
    data['grep_stat'] = data.cor.astype(float)/data.cor_std.astype(float)
    data['pval'] = scipy.stats.norm.sf(abs(data['grep_stat']))*2
    data['pval_fdr'] = fdrcorrection(data.pval)[1]
    data['p2'] = data.index
    PVAL_CUTOFF = 0.05/data.shape[0]
    data['significant_bf'] = ''
    data['significant_fdr'] = ''
    if BONFERRONI:
        data.loc[data.pval<PVAL_CUTOFF, ['significant_bf']] = '*'
    if FDR:
        data.loc[data.pval_fdr<0.05, ['significant_fdr']] = '+'
    data['significant'] = data.significant_bf + data.significant_fdr
    return data

# %%
# g, h = list(gest_data.index), list(hypt_data.index)
# len(g), len(h), len(set(g)), len(set(h)), len(set(g) & set(h))

# %%
gest_data  = return_df(GEST)
hypt_data = return_df(HYPT)
vomt_data = return_df(VOMT)
hprt_data = return_df(HPRT)
gest_data  = count_sign(gest_data)
hypt_data = count_sign(hypt_data)
vomt_data = count_sign(vomt_data)
hprt_data = count_sign(hprt_data)
display(gest_data)
display(hypt_data)
display(vomt_data)
display(hprt_data)
# Out:
#                                                     Cor_All        cor  \
# AB1_BACTINF_NOS                                     Cor_All   0.538912
# AB1_BACT_INTEST_OTH                                 Cor_All   0.496793
# AB1_CANDIDIASIS                                     Cor_All   0.714293
# AB1_GASTROENTERITIS_NOS                             Cor_All   0.472679
# AB1_INFECTIONS                                      Cor_All   0.522366
# ...                                                     ...        ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     Cor_All   0.052886
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             Cor_All   0.028002
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Cor_All  -0.295997
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            Cor_All   1.004349
# Z21_SUPERV_HIGH_R_PREGNAC                           Cor_All   0.810407
#
#                                                      cor_std          trait  \
# AB1_BACTINF_NOS                                     0.201296  GEST_DIABETES
# AB1_BACT_INTEST_OTH                                 1.225783  GEST_DIABETES
# AB1_CANDIDIASIS                                     0.934676  GEST_DIABETES
# AB1_GASTROENTERITIS_NOS                             0.424947  GEST_DIABETES
# AB1_INFECTIONS                                      0.238934  GEST_DIABETES
# ...                                                      ...            ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.184335  GEST_DIABETES
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.202449  GEST_DIABETES
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.257120  GEST_DIABETES
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.869686  GEST_DIABETES
# Z21_SUPERV_HIGH_R_PREGNAC                           0.631482  GEST_DIABETES
#
#                                                     grep_stat      pval  \
# AB1_BACTINF_NOS                                      2.677212  0.007424
# AB1_BACT_INTEST_OTH                                  0.405286  0.685267
# AB1_CANDIDIASIS                                      0.764215  0.444739
# AB1_GASTROENTERITIS_NOS                              1.112325  0.265999
# AB1_INFECTIONS                                       2.186236  0.028798
# ...                                                       ...       ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS      0.286902  0.774188
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE              0.138316  0.889990
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  -1.151202  0.249649
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD             1.154841  0.248156
# Z21_SUPERV_HIGH_R_PREGNAC                            1.283341  0.199372
#
#                                                     pval_fdr  \
# AB1_BACTINF_NOS                                     0.066275
# AB1_BACT_INTEST_OTH                                 0.911610
# AB1_CANDIDIASIS                                     0.789857
# AB1_GASTROENTERITIS_NOS                             0.646211
# AB1_INFECTIONS                                      0.180778
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.934433
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.962535
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.623738
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.622198
# Z21_SUPERV_HIGH_R_PREGNAC                           0.560328
#
#                                                                                                    p2  \
# AB1_BACTINF_NOS                                                                       AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH                                                               AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS                                                                       AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS                                                       AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS                                                                         AB1_INFECTIONS
# ...                                                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS       Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE                       Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_D...
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD                     Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC                                                   Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_bf  \
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                           ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_fdr significant
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                            ...         ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
# [860 rows x 11 columns]
#                                                     Cor_All        cor  \
# AB1_BACTINF_NOS                                     Cor_All   0.421722
# AB1_BACT_INTEST_OTH                                 Cor_All   0.117067
# AB1_CANDIDIASIS                                     Cor_All  -0.552782
# AB1_GASTROENTERITIS_NOS                             Cor_All   0.308142
# AB1_INFECTIONS                                      Cor_All   0.215657
# ...                                                     ...        ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     Cor_All   0.450626
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             Cor_All   0.341246
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Cor_All  -0.572918
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            Cor_All   0.481440
# Z21_SUPERV_HIGH_R_PREGNAC                           Cor_All   0.113246
#
#                                                      cor_std           trait  \
# AB1_BACTINF_NOS                                     0.176204  I9_HYPTENSPREG
# AB1_BACT_INTEST_OTH                                 0.283317  I9_HYPTENSPREG
# AB1_CANDIDIASIS                                     0.766716  I9_HYPTENSPREG
# AB1_GASTROENTERITIS_NOS                             0.146515  I9_HYPTENSPREG
# AB1_INFECTIONS                                      0.099965  I9_HYPTENSPREG
# ...                                                      ...             ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.157268  I9_HYPTENSPREG
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.227455  I9_HYPTENSPREG
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.262027  I9_HYPTENSPREG
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.770888  I9_HYPTENSPREG
# Z21_SUPERV_HIGH_R_PREGNAC                           0.272941  I9_HYPTENSPREG
#
#                                                     grep_stat      pval  \
# AB1_BACTINF_NOS                                      2.393374  0.016694
# AB1_BACT_INTEST_OTH                                  0.413201  0.679459
# AB1_CANDIDIASIS                                     -0.720974  0.470926
# AB1_GASTROENTERITIS_NOS                              2.103143  0.035453
# AB1_INFECTIONS                                       2.157325  0.030980
# ...                                                       ...       ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS      2.865338  0.004166
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE              1.500279  0.133542
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  -2.186485  0.028780
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD             0.624527  0.532282
# Z21_SUPERV_HIGH_R_PREGNAC                            0.414910  0.678208
#
#                                                     pval_fdr  \
# AB1_BACTINF_NOS                                     0.157770
# AB1_BACT_INTEST_OTH                                 0.930469
# AB1_CANDIDIASIS                                     0.843550
# AB1_GASTROENTERITIS_NOS                             0.245886
# AB1_INFECTIONS                                      0.227719
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.056864
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.524412
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.215226
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.875576
# Z21_SUPERV_HIGH_R_PREGNAC                           0.930469
#
#                                                                                                    p2  \
# AB1_BACTINF_NOS                                                                       AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH                                                               AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS                                                                       AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS                                                       AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS                                                                         AB1_INFECTIONS
# ...                                                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS       Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE                       Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_D...
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD                     Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC                                                   Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_bf  \
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                           ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_fdr significant
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                            ...         ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
# [860 rows x 11 columns]
#                                                     Cor_All        cor  \
# AB1_BACTINF_NOS                                     Cor_All   0.591617
# AB1_BACT_INTEST_OTH                                 Cor_All   0.674803
# AB1_CANDIDIASIS                                     Cor_All  -0.304160
# AB1_GASTROENTERITIS_NOS                             Cor_All   1.496180
# AB1_INFECTIONS                                      Cor_All   1.355828
# ...                                                     ...        ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     Cor_All   0.634431
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             Cor_All   0.119258
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Cor_All   1.502852
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            Cor_All   0.572200
# Z21_SUPERV_HIGH_R_PREGNAC                           Cor_All   2.370112
#
#                                                      cor_std  \
# AB1_BACTINF_NOS                                     0.496331
# AB1_BACT_INTEST_OTH                                 1.633649
# AB1_CANDIDIASIS                                     1.205404
# AB1_GASTROENTERITIS_NOS                             0.981609
# AB1_INFECTIONS                                      0.745581
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.473453
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.466003
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.930034
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.518828
# Z21_SUPERV_HIGH_R_PREGNAC                           2.067671
#
#                                                                     trait  \
# AB1_BACTINF_NOS                                     O15_EXCESS_VOMIT_PREG
# AB1_BACT_INTEST_OTH                                 O15_EXCESS_VOMIT_PREG
# AB1_CANDIDIASIS                                     O15_EXCESS_VOMIT_PREG
# AB1_GASTROENTERITIS_NOS                             O15_EXCESS_VOMIT_PREG
# AB1_INFECTIONS                                      O15_EXCESS_VOMIT_PREG
# ...                                                                   ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     O15_EXCESS_VOMIT_PREG
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             O15_EXCESS_VOMIT_PREG
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  O15_EXCESS_VOMIT_PREG
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            O15_EXCESS_VOMIT_PREG
# Z21_SUPERV_HIGH_R_PREGNAC                           O15_EXCESS_VOMIT_PREG
#
#                                                     grep_stat      pval  \
# AB1_BACTINF_NOS                                      1.191981  0.233269
# AB1_BACT_INTEST_OTH                                  0.413065  0.679559
# AB1_CANDIDIASIS                                     -0.252330  0.800786
# AB1_GASTROENTERITIS_NOS                              1.524212  0.127456
# AB1_INFECTIONS                                       1.818485  0.068990
# ...                                                       ...       ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS      1.340008  0.180243
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE              0.255917  0.798015
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA   1.615911  0.106114
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD             1.102870  0.270083
# Z21_SUPERV_HIGH_R_PREGNAC                            1.146271  0.251683
#
#                                                     pval_fdr  \
# AB1_BACTINF_NOS                                     0.929492
# AB1_BACT_INTEST_OTH                                 0.950482
# AB1_CANDIDIASIS                                     0.952547
# AB1_GASTROENTERITIS_NOS                             0.929492
# AB1_INFECTIONS                                      0.929492
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.929492
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.952547
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.929492
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.929492
# Z21_SUPERV_HIGH_R_PREGNAC                           0.929492
#
#                                                                                                    p2  \
# AB1_BACTINF_NOS                                                                       AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH                                                               AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS                                                                       AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS                                                       AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS                                                                         AB1_INFECTIONS
# ...                                                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS       Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE                       Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_D...
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD                     Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC                                                   Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_bf  \
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                           ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_fdr significant
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                            ...         ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
# [860 rows x 11 columns]
#                                                     Cor_All        cor  \
# AB1_BACTINF_NOS                                     Cor_All   0.326080
# AB1_BACT_INTEST_OTH                                 Cor_All   0.088091
# AB1_CANDIDIASIS                                     Cor_All  -0.546461
# AB1_GASTROENTERITIS_NOS                             Cor_All   0.230596
# AB1_INFECTIONS                                      Cor_All   0.176180
# ...                                                     ...        ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     Cor_All   0.373574
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             Cor_All   0.210194
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Cor_All  -0.357972
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            Cor_All   0.325529
# Z21_SUPERV_HIGH_R_PREGNAC                           Cor_All   0.214093
#
#                                                      cor_std  \
# AB1_BACTINF_NOS                                     0.192789
# AB1_BACT_INTEST_OTH                                 0.305635
# AB1_CANDIDIASIS                                     0.776607
# AB1_GASTROENTERITIS_NOS                             0.140439
# AB1_INFECTIONS                                      0.110236
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.155309
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.230249
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.211924
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.541916
# Z21_SUPERV_HIGH_R_PREGNAC                           0.302698
#
#                                                                 trait  \
# AB1_BACTINF_NOS                                     O15_GESTAT_HYPERT
# AB1_BACT_INTEST_OTH                                 O15_GESTAT_HYPERT
# AB1_CANDIDIASIS                                     O15_GESTAT_HYPERT
# AB1_GASTROENTERITIS_NOS                             O15_GESTAT_HYPERT
# AB1_INFECTIONS                                      O15_GESTAT_HYPERT
# ...                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     O15_GESTAT_HYPERT
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             O15_GESTAT_HYPERT
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  O15_GESTAT_HYPERT
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            O15_GESTAT_HYPERT
# Z21_SUPERV_HIGH_R_PREGNAC                           O15_GESTAT_HYPERT
#
#                                                     grep_stat      pval  \
# AB1_BACTINF_NOS                                      1.691383  0.090764
# AB1_BACT_INTEST_OTH                                  0.288223  0.773176
# AB1_CANDIDIASIS                                     -0.703652  0.481650
# AB1_GASTROENTERITIS_NOS                              1.641966  0.100597
# AB1_INFECTIONS                                       1.598207  0.109997
# ...                                                       ...       ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS      2.405360  0.016157
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE              0.912899  0.361296
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  -1.689153  0.091190
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD             0.600700  0.548040
# Z21_SUPERV_HIGH_R_PREGNAC                            0.707283  0.479391
#
#                                                     pval_fdr  \
# AB1_BACTINF_NOS                                     0.560897
# AB1_BACT_INTEST_OTH                                 0.937238
# AB1_CANDIDIASIS                                     0.892705
# AB1_GASTROENTERITIS_NOS                             0.575938
# AB1_INFECTIONS                                      0.594951
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.217104
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.861247
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.560897
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.893979
# Z21_SUPERV_HIGH_R_PREGNAC                           0.892705
#
#                                                                                                    p2  \
# AB1_BACTINF_NOS                                                                       AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH                                                               AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS                                                                       AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS                                                       AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS                                                                         AB1_INFECTIONS
# ...                                                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS       Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE                       Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_D...
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD                     Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC                                                   Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_bf  \
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                           ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_fdr significant
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                            ...         ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
# [860 rows x 11 columns]

# %%
concatted_data = pd.concat([gest_data, hypt_data, vomt_data, hprt_data])
concatted_data
# Out:
#                                                     Cor_All        cor  \
# AB1_BACTINF_NOS                                     Cor_All   0.538912
# AB1_BACT_INTEST_OTH                                 Cor_All   0.496793
# AB1_CANDIDIASIS                                     Cor_All   0.714293
# AB1_GASTROENTERITIS_NOS                             Cor_All   0.472679
# AB1_INFECTIONS                                      Cor_All   0.522366
# ...                                                     ...        ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     Cor_All   0.373574
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             Cor_All   0.210194
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Cor_All  -0.357972
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            Cor_All   0.325529
# Z21_SUPERV_HIGH_R_PREGNAC                           Cor_All   0.214093
#
#                                                      cor_std  \
# AB1_BACTINF_NOS                                     0.201296
# AB1_BACT_INTEST_OTH                                 1.225783
# AB1_CANDIDIASIS                                     0.934676
# AB1_GASTROENTERITIS_NOS                             0.424947
# AB1_INFECTIONS                                      0.238934
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.155309
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.230249
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.211924
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.541916
# Z21_SUPERV_HIGH_R_PREGNAC                           0.302698
#
#                                                                 trait  \
# AB1_BACTINF_NOS                                         GEST_DIABETES
# AB1_BACT_INTEST_OTH                                     GEST_DIABETES
# AB1_CANDIDIASIS                                         GEST_DIABETES
# AB1_GASTROENTERITIS_NOS                                 GEST_DIABETES
# AB1_INFECTIONS                                          GEST_DIABETES
# ...                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     O15_GESTAT_HYPERT
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             O15_GESTAT_HYPERT
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  O15_GESTAT_HYPERT
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            O15_GESTAT_HYPERT
# Z21_SUPERV_HIGH_R_PREGNAC                           O15_GESTAT_HYPERT
#
#                                                     grep_stat      pval  \
# AB1_BACTINF_NOS                                      2.677212  0.007424
# AB1_BACT_INTEST_OTH                                  0.405286  0.685267
# AB1_CANDIDIASIS                                      0.764215  0.444739
# AB1_GASTROENTERITIS_NOS                              1.112325  0.265999
# AB1_INFECTIONS                                       2.186236  0.028798
# ...                                                       ...       ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS      2.405360  0.016157
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE              0.912899  0.361296
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  -1.689153  0.091190
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD             0.600700  0.548040
# Z21_SUPERV_HIGH_R_PREGNAC                            0.707283  0.479391
#
#                                                     pval_fdr  \
# AB1_BACTINF_NOS                                     0.066275
# AB1_BACT_INTEST_OTH                                 0.911610
# AB1_CANDIDIASIS                                     0.789857
# AB1_GASTROENTERITIS_NOS                             0.646211
# AB1_INFECTIONS                                      0.180778
# ...                                                      ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS     0.217104
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE             0.861247
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  0.560897
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD            0.893979
# Z21_SUPERV_HIGH_R_PREGNAC                           0.892705
#
#                                                                                                    p2  \
# AB1_BACTINF_NOS                                                                       AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH                                                               AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS                                                                       AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS                                                       AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS                                                                         AB1_INFECTIONS
# ...                                                                                               ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS       Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE                       Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA  Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_D...
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD                     Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC                                                   Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_bf  \
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                           ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
#                                                    significant_fdr significant
# AB1_BACTINF_NOS
# AB1_BACT_INTEST_OTH
# AB1_CANDIDIASIS
# AB1_GASTROENTERITIS_NOS
# AB1_INFECTIONS
# ...                                                            ...         ...
# Z21_PRESENCE_CARDIAC_VASCULAR_IMPLANTNTS_GRAFTS
# Z21_PROCED_PURPO_OTH_REMED_HEALTH_STATE
# Z21_SPECIAL_SCREEN_EXAM_INFECTIOUS_PARASITIC_DISEA
# Z21_SPECIAL_SCREEN_EXAM_OTH_DISEA_DISORD
# Z21_SUPERV_HIGH_R_PREGNAC
#
# [3440 rows x 11 columns]

# %%
filtered_concatted_data = concatted_data[concatted_data.significant!='']
cd_final = concatted_data[concatted_data.p2.isin(set(filtered_concatted_data.index))]
cd_final
# Out:
#                                                     Cor_All        cor  \
# E4_DIABETES                                         Cor_All   1.107069
# E4_OBESITY                                          Cor_All   0.680994
# FG_DOAAC                                            Cor_All   0.446735
# FG_OTHHEART                                         Cor_All   0.313117
# G6_NERPLEX                                          Cor_All   0.845052
# ...                                                     ...        ...
# O15_PREG_MATERN_CARE                                Cor_All  -0.097986
# O15_PREG_OTHER_MAT_DISORD                           Cor_All   0.174033
# O15_PRE_OR_ECLAMPSIA                                Cor_All   0.987726
# R18_DIZZI_GIDDI                                     Cor_All   0.687925
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Cor_All   0.221240
#
#                                                      cor_std  \
# E4_DIABETES                                         0.193941
# E4_OBESITY                                          0.187512
# FG_DOAAC                                            0.126326
# FG_OTHHEART                                         0.139646
# G6_NERPLEX                                          0.152787
# ...                                                      ...
# O15_PREG_MATERN_CARE                                0.272672
# O15_PREG_OTHER_MAT_DISORD                           0.119531
# O15_PRE_OR_ECLAMPSIA                                0.132211
# R18_DIZZI_GIDDI                                     0.166724
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.104088
#
#                                                                 trait  \
# E4_DIABETES                                             GEST_DIABETES
# E4_OBESITY                                              GEST_DIABETES
# FG_DOAAC                                                GEST_DIABETES
# FG_OTHHEART                                             GEST_DIABETES
# G6_NERPLEX                                              GEST_DIABETES
# ...                                                               ...
# O15_PREG_MATERN_CARE                                O15_GESTAT_HYPERT
# O15_PREG_OTHER_MAT_DISORD                           O15_GESTAT_HYPERT
# O15_PRE_OR_ECLAMPSIA                                O15_GESTAT_HYPERT
# R18_DIZZI_GIDDI                                     O15_GESTAT_HYPERT
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  O15_GESTAT_HYPERT
#
#                                                     grep_stat          pval  \
# E4_DIABETES                                          5.708277  1.141254e-08
# E4_OBESITY                                           3.631736  2.815215e-04
# FG_DOAAC                                             3.536366  4.056719e-04
# FG_OTHHEART                                          2.242220  2.494718e-02
# G6_NERPLEX                                           5.530916  3.185636e-08
# ...                                                       ...           ...
# O15_PREG_MATERN_CARE                                -0.359355  7.193297e-01
# O15_PREG_OTHER_MAT_DISORD                            1.455965  1.454022e-01
# O15_PRE_OR_ECLAMPSIA                                 7.470831  7.969012e-14
# R18_DIZZI_GIDDI                                      4.126131  3.689178e-05
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS   2.125509  3.354415e-02
#
#                                                         pval_fdr  \
# E4_DIABETES                                         1.962957e-06
# E4_OBESITY                                          7.336621e-03
# FG_DOAAC                                            8.721946e-03
# FG_OTHHEART                                         1.650352e-01
# G6_NERPLEX                                          4.523593e-06
# ...                                                          ...
# O15_PREG_MATERN_CARE                                9.313002e-01
# O15_PREG_OTHER_MAT_DISORD                           6.555842e-01
# O15_PRE_OR_ECLAMPSIA                                7.614834e-12
# R18_DIZZI_GIDDI                                     1.982933e-03
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  3.135649e-01
#
#                                                                                                    p2  \
# E4_DIABETES                                                                               E4_DIABETES
# E4_OBESITY                                                                                 E4_OBESITY
# FG_DOAAC                                                                                     FG_DOAAC
# FG_OTHHEART                                                                               FG_OTHHEART
# G6_NERPLEX                                                                                 G6_NERPLEX
# ...                                                                                               ...
# O15_PREG_MATERN_CARE                                                             O15_PREG_MATERN_CARE
# O15_PREG_OTHER_MAT_DISORD                                                   O15_PREG_OTHER_MAT_DISORD
# O15_PRE_OR_ECLAMPSIA                                                             O15_PRE_OR_ECLAMPSIA
# R18_DIZZI_GIDDI                                                                       R18_DIZZI_GIDDI
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYS...
#
#                                                    significant_bf  \
# E4_DIABETES                                                     *
# E4_OBESITY
# FG_DOAAC
# FG_OTHHEART
# G6_NERPLEX                                                      *
# ...                                                           ...
# O15_PREG_MATERN_CARE
# O15_PREG_OTHER_MAT_DISORD
# O15_PRE_OR_ECLAMPSIA                                            *
# R18_DIZZI_GIDDI                                                 *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
#
#                                                    significant_fdr significant
# E4_DIABETES                                                                  *
# E4_OBESITY
# FG_DOAAC
# FG_OTHHEART
# G6_NERPLEX                                                                   *
# ...                                                            ...         ...
# O15_PREG_MATERN_CARE
# O15_PREG_OTHER_MAT_DISORD
# O15_PRE_OR_ECLAMPSIA                                                         *
# R18_DIZZI_GIDDI                                                              *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
#
# [164 rows x 11 columns]

# %%
final = pd.merge(cd_final, fu,  how="left", left_index=True, right_index=True)

assert final[final.full_name.isna()].shape[0] == 0

col_rename = {"cor": "rg", "cor_std": "se", "trait": "p1", "grep_stat": "z", "pval": "p", "p2": "p2"}
final = final.rename(columns=col_rename)

final.p1 = final.p1.apply(lambda x: ph_map[x])
final.p2 = final.full_name


print(final.shape)
final
# Out:
# (164, 13)
#                                                     Cor_All        rg  \
# E4_DIABETES                                         Cor_All  1.107069
# E4_DIABETES                                         Cor_All  0.400351
# E4_DIABETES                                         Cor_All  0.485316
# E4_DIABETES                                         Cor_All  0.283170
# E4_OBESITY                                          Cor_All  0.680994
# ...                                                     ...       ...
# R18_DIZZI_GIDDI                                     Cor_All  0.687925
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Cor_All  0.568640
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Cor_All  0.301865
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Cor_All  0.715299
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Cor_All  0.221240
#
#                                                           se  p1         z  \
# E4_DIABETES                                         0.193941  GD  5.708277
# E4_DIABETES                                         0.061134  HP  6.548745
# E4_DIABETES                                         0.332880  EV  1.457931
# E4_DIABETES                                         0.060705  GH  4.664690
# E4_OBESITY                                          0.187512  GD  3.631736
# ...                                                      ...  ..       ...
# R18_DIZZI_GIDDI                                     0.166724  GH  4.126131
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.133631  GD  4.255300
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.098061  HP  3.078339
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.468161  EV  1.527891
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.104088  GH  2.125509
#
#                                                                p  \
# E4_DIABETES                                         1.141254e-08
# E4_DIABETES                                         5.802246e-11
# E4_DIABETES                                         1.448596e-01
# E4_DIABETES                                         3.090828e-06
# E4_OBESITY                                          2.815215e-04
# ...                                                          ...
# R18_DIZZI_GIDDI                                     3.689178e-05
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  2.087689e-05
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  2.081580e-03
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  1.265396e-01
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  3.354415e-02
#
#                                                         pval_fdr  \
# E4_DIABETES                                         1.962957e-06
# E4_DIABETES                                         4.158276e-09
# E4_DIABETES                                         9.294918e-01
# E4_DIABETES                                         2.044702e-04
# E4_OBESITY                                          7.336621e-03
# ...                                                          ...
# R18_DIZZI_GIDDI                                     1.982933e-03
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  1.122133e-03
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  3.315109e-02
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  9.294918e-01
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  3.135649e-01
#
#                                                                                                    p2  \
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_OBESITY                                                                                    Obesity
# ...                                                                                               ...
# R18_DIZZI_GIDDI                                                               Dizziness and giddiness
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
#
#                                                    significant_bf  \
# E4_DIABETES                                                     *
# E4_DIABETES                                                     *
# E4_DIABETES
# E4_DIABETES                                                     *
# E4_OBESITY
# ...                                                           ...
# R18_DIZZI_GIDDI                                                 *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS              *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
#
#                                                    significant_fdr  \
# E4_DIABETES
# E4_DIABETES
# E4_DIABETES
# E4_DIABETES
# E4_OBESITY
# ...                                                            ...
# R18_DIZZI_GIDDI
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
#
#                                                    significant  \
# E4_DIABETES                                                  *
# E4_DIABETES                                                  *
# E4_DIABETES
# E4_DIABETES                                                  *
# E4_OBESITY
# ...                                                        ...
# R18_DIZZI_GIDDI                                              *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS           *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
#
#                                                                                                     0  \
# E4_DIABETES                                                                               E4_DIABETES
# E4_DIABETES                                                                               E4_DIABETES
# E4_DIABETES                                                                               E4_DIABETES
# E4_DIABETES                                                                               E4_DIABETES
# E4_OBESITY                                                                                 E4_OBESITY
# ...                                                                                               ...
# R18_DIZZI_GIDDI                                                                       R18_DIZZI_GIDDI
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYS...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYS...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYS...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYS...
#
#                                                                                             full_name
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_OBESITY                                                                                    Obesity
# ...                                                                                               ...
# R18_DIZZI_GIDDI                                                               Dizziness and giddiness
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
#
# [164 rows x 13 columns]

# %%
for c in ['I9_OTHHEART', 'FG_OTHHEART']:
    final.loc[final.index==c, 'p2'] = f'{c}: '+ final[final.index==c].p2

# %%
# Check if p2 is correlated with itself (and only with itself)

# %%
final[final.index.isin(set(final.index.unique())&set(ph_map.keys()))]
# Out:
#                        Cor_All        rg        se  p1             z  \
# GEST_DIABETES          Cor_All  1.000274  0.000331  GD   3021.975831
# GEST_DIABETES          Cor_All  0.339312  0.121080  HP      2.802379
# GEST_DIABETES          Cor_All  0.847602  0.532323  EV      1.592270
# GEST_DIABETES          Cor_All  0.290859  0.134381  GH      2.164435
# I9_HYPTENSPREG         Cor_All  0.339312  0.121080  GD      2.802379
# I9_HYPTENSPREG         Cor_All  1.000058  0.000052  HP  19231.884615
# I9_HYPTENSPREG         Cor_All  0.127947  0.309521  EV      0.413371
# I9_HYPTENSPREG         Cor_All  1.018880  0.032024  GH     31.816138
# O15_EXCESS_VOMIT_PREG  Cor_All  0.847602  0.532323  GD      1.592270
# O15_EXCESS_VOMIT_PREG  Cor_All  0.127947  0.309521  HP      0.413371
# O15_EXCESS_VOMIT_PREG  Cor_All  1.000584  0.000733  EV   1365.053206
# O15_EXCESS_VOMIT_PREG  Cor_All  0.169398  0.338145  GH      0.500963
# O15_GESTAT_HYPERT      Cor_All  0.290859  0.134381  GD      2.164435
# O15_GESTAT_HYPERT      Cor_All  1.018880  0.032024  HP     31.816138
# O15_GESTAT_HYPERT      Cor_All  0.169398  0.338145  EV      0.500963
# O15_GESTAT_HYPERT      Cor_All  1.000008  0.000013  GH  76923.692308
#
#                                    p       pval_fdr  \
# GEST_DIABETES           0.000000e+00   0.000000e+00
# GEST_DIABETES           5.072731e-03   6.511266e-02
# GEST_DIABETES           1.113240e-01   9.294918e-01
# GEST_DIABETES           3.043095e-02   3.067286e-01
# I9_HYPTENSPREG          5.072731e-03   5.132410e-02
# I9_HYPTENSPREG          0.000000e+00   0.000000e+00
# I9_HYPTENSPREG          6.793348e-01   9.504818e-01
# I9_HYPTENSPREG         3.872208e-222  1.110033e-219
# O15_EXCESS_VOMIT_PREG   1.113240e-01   4.411920e-01
# O15_EXCESS_VOMIT_PREG   6.793348e-01   9.304693e-01
# O15_EXCESS_VOMIT_PREG   0.000000e+00   0.000000e+00
# O15_EXCESS_VOMIT_PREG   6.163974e-01   9.047300e-01
# O15_GESTAT_HYPERT       3.043095e-02   1.861773e-01
# O15_GESTAT_HYPERT      3.872208e-222  8.325247e-220
# O15_GESTAT_HYPERT       6.163974e-01   9.496536e-01
# O15_GESTAT_HYPERT       0.000000e+00   0.000000e+00
#
#                                                                       p2  \
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
#
#                       significant_bf significant_fdr significant  \
# GEST_DIABETES                      *                           *
# GEST_DIABETES
# GEST_DIABETES
# GEST_DIABETES
# I9_HYPTENSPREG
# I9_HYPTENSPREG                     *                           *
# I9_HYPTENSPREG
# I9_HYPTENSPREG                     *                           *
# O15_EXCESS_VOMIT_PREG
# O15_EXCESS_VOMIT_PREG
# O15_EXCESS_VOMIT_PREG              *                           *
# O15_EXCESS_VOMIT_PREG
# O15_GESTAT_HYPERT
# O15_GESTAT_HYPERT                  *                           *
# O15_GESTAT_HYPERT
# O15_GESTAT_HYPERT                  *                           *
#
#                                            0  \
# GEST_DIABETES                  GEST_DIABETES
# GEST_DIABETES                  GEST_DIABETES
# GEST_DIABETES                  GEST_DIABETES
# GEST_DIABETES                  GEST_DIABETES
# I9_HYPTENSPREG                I9_HYPTENSPREG
# I9_HYPTENSPREG                I9_HYPTENSPREG
# I9_HYPTENSPREG                I9_HYPTENSPREG
# I9_HYPTENSPREG                I9_HYPTENSPREG
# O15_EXCESS_VOMIT_PREG  O15_EXCESS_VOMIT_PREG
# O15_EXCESS_VOMIT_PREG  O15_EXCESS_VOMIT_PREG
# O15_EXCESS_VOMIT_PREG  O15_EXCESS_VOMIT_PREG
# O15_EXCESS_VOMIT_PREG  O15_EXCESS_VOMIT_PREG
# O15_GESTAT_HYPERT          O15_GESTAT_HYPERT
# O15_GESTAT_HYPERT          O15_GESTAT_HYPERT
# O15_GESTAT_HYPERT          O15_GESTAT_HYPERT
# O15_GESTAT_HYPERT          O15_GESTAT_HYPERT
#
#                                                                full_name
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# GEST_DIABETES                       Gestational diabetes (for exclusion)
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# I9_HYPTENSPREG         Hypertension complicating pregnancy, childbirt...
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_EXCESS_VOMIT_PREG                    Excessive vomiting in pregnancy
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension
# O15_GESTAT_HYPERT           Gestational [pregnancy-induced] hypertension

# %% [markdown]
# `O15_EXCESS_VOMIT_PREG` and `GEST_DIABETES` from p2 is correlated only with itself from p1 => delete it.

# %%
final = final[~final.index.isin(['O15_EXCESS_VOMIT_PREG', 'GEST_DIABETES'])]

# %%
ph_map.values()
# Out:
# dict_values(['HP', 'GD', 'GH', 'EV'])

# %%
for k in ph_map.values():
    print(k)
    dk = final[(final.p1==k) & (final.significant!='')]
    print(dk.shape)
#     display(dk)
# Out:
# HP
# (29, 13)
# GD
# (17, 13)
# GH
# (16, 13)
# EV
# (0, 13)

# %%
29+17+16
# Out:
# 62

# %%
data_to_save = final.loc[:,['p1', 'p2', 'rg', 'se', 'z', 'p', 'significant']]
data_to_save.to_csv('./out_data_fg/feature.csv', index=True)
data_to_save
# Out:
#                                                     p1  \
# E4_DIABETES                                         GD
# E4_DIABETES                                         HP
# E4_DIABETES                                         EV
# E4_DIABETES                                         GH
# E4_OBESITY                                          GD
# ...                                                 ..
# R18_DIZZI_GIDDI                                     GH
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  GD
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  HP
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  EV
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  GH
#
#                                                                                                    p2  \
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_DIABETES                                                                         Diabetes mellitus
# E4_OBESITY                                                                                    Obesity
# ...                                                                                               ...
# R18_DIZZI_GIDDI                                                               Dizziness and giddiness
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  Symptoms and signs involving the circulatory a...
#
#                                                           rg        se  \
# E4_DIABETES                                         1.107069  0.193941
# E4_DIABETES                                         0.400351  0.061134
# E4_DIABETES                                         0.485316  0.332880
# E4_DIABETES                                         0.283170  0.060705
# E4_OBESITY                                          0.680994  0.187512
# ...                                                      ...       ...
# R18_DIZZI_GIDDI                                     0.687925  0.166724
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.568640  0.133631
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.301865  0.098061
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.715299  0.468161
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  0.221240  0.104088
#
#                                                            z             p  \
# E4_DIABETES                                         5.708277  1.141254e-08
# E4_DIABETES                                         6.548745  5.802246e-11
# E4_DIABETES                                         1.457931  1.448596e-01
# E4_DIABETES                                         4.664690  3.090828e-06
# E4_OBESITY                                          3.631736  2.815215e-04
# ...                                                      ...           ...
# R18_DIZZI_GIDDI                                     4.126131  3.689178e-05
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  4.255300  2.087689e-05
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  3.078339  2.081580e-03
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  1.527891  1.265396e-01
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS  2.125509  3.354415e-02
#
#                                                    significant
# E4_DIABETES                                                  *
# E4_DIABETES                                                  *
# E4_DIABETES
# E4_DIABETES                                                  *
# E4_OBESITY
# ...                                                        ...
# R18_DIZZI_GIDDI                                              *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS           *
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
# R18_SYMPTOMS_SIGNS_INVOLVI_CIRCULATO_RESPI_SYSTEMS
#
# [156 rows x 7 columns]

# %%
cols_supp = ['Soft tissue disorders',
'Diseases of the musculoskeletal system and connective tissue',
'Peripheral artery disease',
'Major coronary heart disease event',
'Hypertension, essential',
'Heart failure and antihypertensive medication',
'Myocardial infarction',
'Ischemic heart diseases',
'Diabetes mellitus',
'Obesity',]

cols_not_supp = ['Polyarthropathies',
'Nerve, nerve root and plexus disorders',
'Gastrointestinal diseases',
'Diseases of the ear and mastoid process',
'Dizziness and giddiness',]
print(len(cols_supp), len(cols_not_supp))
# Out:
# 10 5

# %%
data_to_save[data_to_save.p2.isin(cols_supp)].to_csv('./out_data_fg/feature_supp.csv', index=True)
data_to_save[data_to_save.p2.isin(cols_not_supp)].to_csv('./out_data_fg/feature_not_supp.csv', index=True)

# %%
# data_to_save[data_to_save.p2 != 'O15_PRETERM___O60'].to_csv('./data/feature4.csv', index=False)

# %%
156/4
# Out:
# 39.0
